# %%
import requests
from bs4 import BeautifulSoup

r = requests.get("http://www.pyclass.com/real-estate/rock-springs-wy/LCWYROCKSPRINGS/", headers={'User-agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:61.0) Gecko/20100101 Firefox/61.0'})
c=r.content

soup=BeautifulSoup(c,"html.parser")

all=soup.find_all("div",{"class":"propertyRow"})

all[0].find("h4", {"class":"propPrice"}).text.replace("\n","").replace(" ","")
page_nr=soup.find_all("a", {"class":"Page"})[-1].text

l = []

base_url="http://www.pyclass.com/real-estate/rock-springs-wy/LCWYROCKSPRINGS/#t=0&s="
for page in range(0,int(page_nr)*10,10):
    print(base_url+str(page))
    r=requests.get(base_url+str(page), headers={'User-agent': 'Mozilla/5.0 (X11; Ubuntu; Linux x86_64; rv:61.0) Gecko/20100101 Firefox/61.0'})
    c=r.content
    soup=BeautifulSoup(c,"html.parser")
    all=soup.find_all("div",{"class":"propertyRow"})
    #print(soup.prettify())
    
    for item in all:
        d={}
        d["Address"]=item.find_all("span", {"class":"propAddressCollapse"})[0].text
        d["Locality"]=item.find_all("span", {"class":"propAddressCollapse"})[1].text
        d["Price"]=item.find("h4", {"class":"propPrice"}).text.replace("\n","").replace(" ","")
        try:
            d["Bed"]=item.find("span", {"class":"infoBed"}).find("b").text
        except:
            d["Bed"]=None

        try:
            d["SqFt"]=item.find("span", {"class":"infoSqFt"}).find("b").text
        except:
            d["SqFt"]=None

        try:
            d["Bath"]=item.find("span", {"class":"infoValueFullBath"}).find("b").text
        except:
            d["Bath"]=None

        try:
            d["Half Bath"]=item.find("span", {"class":"infoValueHalfBath"}).find("b").text
        except:
            d["Half Bath"]=None

        for column_group in item.find_all("div",{"class":"columnGroup"}):
            for feature_group, feature_name in zip(column_group.find_all("span",{"class":"featureGroup"}),column_group.find_all("span",{"class":"featureName"})):
                #print(feature_group.text, feature_name.text)
                if "Lot Size" in feature_group.text:
                    d["Lot Size"]=feature_name.text

        l.append(d)
l

import pandas
df=pandas.DataFrame(l)
df
#df.to_csv("Output.csv")
# Out:
# http://www.pyclass.com/real-estate/rock-springs-wy/LCWYROCKSPRINGS/#t=0&s=0
# http://www.pyclass.com/real-estate/rock-springs-wy/LCWYROCKSPRINGS/#t=0&s=10
# http://www.pyclass.com/real-estate/rock-springs-wy/LCWYROCKSPRINGS/#t=0&s=20
#                   Address  Bath   Bed Half Bath                Locality  \
# 0               0 Gateway  None  None      None  Rock Springs, WY 82901
# 1   1003 Winchester Blvd.     4     4      None  Rock Springs, WY 82901
# 2           600 Talladega     3     5      None  Rock Springs, WY 82901
# 3      3239 Spearhead Way     3     4         1  Rock Springs, WY 82901
# 4      522 Emerald Street     3     3      None  Rock Springs, WY 82901
# 5    1302 Veteran's Drive     2     4      None  Rock Springs, WY 82901
# 6        1021 Cypress Cir     3     4      None  Rock Springs, WY 82901
# 7          913 Madison Dr     2     3      None  Rock Springs, WY 82901
# 8       1344 Teton Street     2     3      None  Rock Springs, WY 82901
# 9          4 Minnies Lane     2     3      None  Rock Springs, WY 82901
# 10              0 Gateway  None  None      None  Rock Springs, WY 82901
# 11  1003 Winchester Blvd.     4     4      None  Rock Springs, WY 82901
# 12          600 Talladega     3     5      None  Rock Springs, WY 82901
# 13     3239 Spearhead Way     3     4         1  Rock Springs, WY 82901
# 14     522 Emerald Street     3     3      None  Rock Springs, WY 82901
# 15   1302 Veteran's Drive     2     4      None  Rock Springs, WY 82901
# 16       1021 Cypress Cir     3     4      None  Rock Springs, WY 82901
# 17         913 Madison Dr     2     3      None  Rock Springs, WY 82901
# 18      1344 Teton Street     2     3      None  Rock Springs, WY 82901
# 19         4 Minnies Lane     2     3      None  Rock Springs, WY 82901
# 20              0 Gateway  None  None      None  Rock Springs, WY 82901
# 21  1003 Winchester Blvd.     4     4      None  Rock Springs, WY 82901
# 22          600 Talladega     3     5      None  Rock Springs, WY 82901
# 23     3239 Spearhead Way     3     4         1  Rock Springs, WY 82901
# 24     522 Emerald Street     3     3      None  Rock Springs, WY 82901
# 25   1302 Veteran's Drive     2     4      None  Rock Springs, WY 82901
# 26       1021 Cypress Cir     3     4      None  Rock Springs, WY 82901
# 27         913 Madison Dr     2     3      None  Rock Springs, WY 82901
# 28      1344 Teton Street     2     3      None  Rock Springs, WY 82901
# 29         4 Minnies Lane     2     3      None  Rock Springs, WY 82901
#
#             Lot Size     Price   SqFt
# 0                NaN  $725,000   None
# 1         0.21 Acres  $452,900   None
# 2                NaN  $396,900  3,154
# 3   Under 1/2 Acre,   $389,900  3,076
# 4   Under 1/2 Acre,   $254,000  1,172
# 5         0.27 Acres  $252,900  1,932
# 6   Under 1/2 Acre,   $210,000  1,676
# 7   Under 1/2 Acre,   $209,000  1,344
# 8   Under 1/2 Acre,   $199,900  1,920
# 9         2.02 Acres  $196,900  1,664
# 10               NaN  $725,000   None
# 11        0.21 Acres  $452,900   None
# 12               NaN  $396,900  3,154
# 13  Under 1/2 Acre,   $389,900  3,076
# 14  Under 1/2 Acre,   $254,000  1,172
# 15        0.27 Acres  $252,900  1,932
# 16  Under 1/2 Acre,   $210,000  1,676
# 17  Under 1/2 Acre,   $209,000  1,344
# 18  Under 1/2 Acre,   $199,900  1,920
# 19        2.02 Acres  $196,900  1,664
# 20               NaN  $725,000   None
# 21        0.21 Acres  $452,900   None
# 22               NaN  $396,900  3,154
# 23  Under 1/2 Acre,   $389,900  3,076
# 24  Under 1/2 Acre,   $254,000  1,172
# 25        0.27 Acres  $252,900  1,932
# 26  Under 1/2 Acre,   $210,000  1,676
# 27  Under 1/2 Acre,   $209,000  1,344
# 28  Under 1/2 Acre,   $199,900  1,920
# 29        2.02 Acres  $196,900  1,664
